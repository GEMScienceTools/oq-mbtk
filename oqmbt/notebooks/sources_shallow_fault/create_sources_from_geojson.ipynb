# %%
# %matplotlib inline
import os
import re
import sys
from oqmbt.oqt_project import OQtProject
from oqmbt.notebooks.sources_shallow_fault.create_fault_sources_from_geojson import get_fault_sources
from openquake.hazardlib.tom import PoissonTOM
from openquake.hazardlib.geo.surface import SimpleFaultSurface
from openquake.hazardlib.mfd import EvenlyDiscretizedMFD
from openquake.hazardlib.scalerel.wc1994 import WC1994
from openquake.hazardlib.sourcewriter import write_source_model

# %%
prj_path = "/Users/kjohnson/GEM/Regions/paisl18/project/paisl.oqmbtp"
os.environ["OQMBT_PROJECT"] = prj_path

# %%
project_pickle_filename = os.environ.get('OQMBT_PROJECT')
oqtkp = OQtProject.load_from_file(project_pickle_filename)
model_id = oqtkp.active_model_id
model = oqtkp.models[model_id]

# %% [markdown]
# ## Parameters

# %%
slip_rate_class = 'suggested' 
m_low = model.faults_lower_threshold_magnitude
bin_width = model.mfd_binwidth
scalerel_name = model.msr
rupture_mesh_spacing = model.fault_rupture_mesh_spacing
upper_seismogenic_depth = model.upper_seismogenic_depth
## THIS PARAMETER IS NOT USED BUT THIS PART NEEDS TO BE IMPROVED
lower_seismogenic_depth=10.0 
rupture_aspect_ratio=2.0
temporal_occurrence_model=PoissonTOM(1.0)
aseismic_coeff=0.9
# this is the geojson file
filename = os.path.abspath(os.path.join(oqtkp.directory, model.fault_geojson_filename))

# %% [markdown]
# ## Set the magnitude scaling relationship
# The options available for the magnitude scaling relationship are:
# * `scalrel_name = 'WC1994`' <br> Wells and Coppersmith (1994) scaling relationship
# * '`PointMSR`' Scaling relationship to be used for the creation of tiny ruptures resembling points
# * '`CEUS2011`' Scaling relationship developed within the CEUS SSC project

# %%
import importlib
module = importlib.import_module('openquake.hazardlib.scalerel')
my_class = getattr(module, scalerel_name)
msr = my_class()

# %% [markdown]
# ## Creating the xml file

# %%
b_gr = 1.0 # this is a dummy value that will be modified during following steps
sources = get_fault_sources(filename, 
                            slip_rate_class, 
                            bin_width, 
                            m_low, 
                            b_gr,
                            rupture_mesh_spacing, 
                            upper_seismogenic_depth,
                            lower_seismogenic_depth, 
                            msr,
                            rupture_aspect_ratio, 
                            temporal_occurrence_model,
                            aseismic_coeff)
# Out:
# WARNING:root:Dip direction value is missing for fault with name |  and id 0
# WARNING:root:Mx [6.33] is lesser than Mmin [6.50] for fault with name  |  and id 0
# WARNING:root:Dip direction value is missing for fault with name |  and id 1
# WARNING:root:Dip direction value is missing for fault with name |  and id 2
# WARNING:root:Dip direction value is missing for fault with name |  and id 3
# WARNING:root:Dip direction value is missing for fault with name |  and id 4
# WARNING:root:Dip direction value is missing for fault with name |  and id 5
# WARNING:root:Dip direction value is missing for fault with name |  and id 6
# WARNING:root:Dip direction value is missing for fault with name |  and id 7
# ------------------------------------------------------------------------------
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [23.0, None, None]
# shortening_rate=  [-15.3, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [17.2, None, None]
# mech: Spreading
# Dip value for id= 0 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 0 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 0 is net_slip= 20.7 [slipr = Spreading Ridge]
# mean_azimuth=  308.019912132
# slip_rate=  20.7
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [10.0, None, None]
# shortening_rate=  [5.4, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [8.4, None, None]
# mech: Reverse
# Dip value for id= 1 is missing and was computed using slipt= Reverse, new dip= 30.0
# Rake value for id= 1 is missing and was computed using slipt= Reverse, new rake= 90
# net_slip value for id= 1 is net_slip= 9.0 [slipr = Reverse]
# mean_azimuth=  155.780369325
# slip_rate=  9.0
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [10.1, None, None]
# shortening_rate=  [5.7, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [8.4, None, None]
# mech: Reverse
# Dip value for id= 2 is missing and was computed using slipt= Reverse, new dip= 30.0
# Rake value for id= 2 is missing and was computed using slipt= Reverse, new rake= 90
# net_slip value for id= 2 is net_slip= 9.09 [slipr = Reverse]
# mean_azimuth=  155.799951329
# slip_rate=  9.09
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [141.2, None, None]
# shortening_rate=  [18.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [140.1, None, None]
# mech: Sinistral
# Dip value for id= 3 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 3 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 3 is net_slip= 127.08 [slipr = Sinistral]
# mean_azimuth=  148.628114004
# rld= 56.2365683545, width = 17.0, class= Sinistral
# slip_rate=  127.08
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [140.5, None, None]
# shortening_rate=  [11.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [140.1, None, None]
# mech: Sinistral
# Dip value for id= 4 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 4 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 4 is net_slip= 126.45 [slipr = Sinistral]
# mean_azimuth=  148.521349729
# rld= 56.2948144212, width = 17.0, class= Sinistral
# slip_rate=  126.45
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [140.1, None, None]
# shortening_rate=  [5.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [140.0, None, None]
# mech: Sinistral
# Dip value for id= 5 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 5 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 5 is net_slip= 126.09 [slipr = Sinistral]
# mean_azimuth=  148.704805166
# rld= 56.0459773583, width = 17.0, class= Sinistral
# slip_rate=  126.09
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [139.9, None, None]
# shortening_rate=  [12.8, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [139.3, None, None]
# mech: Sinistral
# Dip value for id= 6 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 6 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 6 is net_slip= 125.91000000000001 [slipr = Sinistral]
# mean_azimuth=  154.091249033
# slip_rate=  125.91000000000001
# right
# dip_dir fazzula=
# WARNING:root:Dip direction value is missing for fault with name |  and id 8
# WARNING:root:Dip direction value is missing for fault with name |  and id 9
# WARNING:root:Dip direction value is missing for fault with name |  and id 10
# WARNING:root:Dip direction value is missing for fault with name |  and id 11
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 11
# WARNING:root:Dip direction value is missing for fault with name |  and id 12
# WARNING:root:Mx [6.20] is lesser than Mmin [6.50] for fault with name  |  and id 12
# WARNING:root:Dip direction value is missing for fault with name |  and id 13
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 13
# WARNING:root:Dip direction value is missing for fault with name |  and id 14
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 14
# WARNING:root:Dip direction value is missing for fault with name |  and id 15
# N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [13.0, None, None]
# shortening_rate=  [0.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [13.0, None, None]
# mech: Sinistral
# Dip value for id= 7 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 7 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 7 is net_slip= 11.700000000000001 [slipr = Sinistral]
# mean_azimuth=  233.662859345
# slip_rate=  11.700000000000001
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [13.0, None, None]
# shortening_rate=  [-0.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [13.0, None, None]
# mech: Sinistral
# Dip value for id= 8 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 8 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 8 is net_slip= 11.700000000000001 [slipr = Sinistral]
# mean_azimuth=  229.244379876
# rld= 69.8715623133, width = 17.0, class= Sinistral
# slip_rate=  11.700000000000001
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [13.0, None, None]
# shortening_rate=  [-0.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [13.0, None, None]
# mech: Sinistral
# Dip value for id= 9 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 9 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 9 is net_slip= 11.700000000000001 [slipr = Sinistral]
# mean_azimuth=  229.208885993
# rld= 70.0165730189, width = 17.0, class= Sinistral
# slip_rate=  11.700000000000001
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [13.0, None, None]
# shortening_rate=  [-0.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [13.0, None, None]
# mech: Sinistral
# Dip value for id= 10 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 10 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 10 is net_slip= 11.700000000000001 [slipr = Sinistral]
# mean_azimuth=  229.147860381
# rld= 70.5090004678, width = 17.0, class= Sinistral
# slip_rate=  11.700000000000001
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [23.5, None, None]
# shortening_rate=  [-23.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.1, None, None]
# mech: Spreading
# Dip value for id= 11 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 11 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 11 is net_slip= 21.150000000000002 [slipr = Spreading Ridge]
# mean_azimuth=  90.3237445649
# slip_rate=  21.150000000000002
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [23.8, None, None]
# shortening_rate=  [3.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [23.6, None, None]
# mech: Sinistral
# Dip value for id= 12 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 12 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 12 is net_slip= 21.42 [slipr = Sinistral]
# mean_azimuth=  178.443052121
# slip_rate=  21.42
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [23.9, None, None]
# shortening_rate=  [-21.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [10.3, None, None]
# mech: Spreading
# Dip value for id= 13 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 13 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 13 is net_slip= 21.509999999999998 [slipr = Spreading Ridge]
# mean_azimuth=  106.938878845
# slip_rate=  21.509999999999998
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [24.2, None, None]
# shortening_rate=  [-23.4, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [6.0, None, None]
# mech: Spreading
# Dip value for id= 14 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 14 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 14 is net_slip= 21.78 [slipr = Spreading Ridge]
# mean_azimuth=  96.557078813
# slip_rate=  21.78
# dip_dir fazzula=
# WARNING:root:Mx [5.66] is lesser than Mmin [6.50] for fault with name  |  and id 15
# WARNING:root:Dip direction value is missing for fault with name |  and id 16
# WARNING:root:Mx [6.33] is lesser than Mmin [6.50] for fault with name  |  and id 16
# WARNING:root:Dip direction value is missing for fault with name |  and id 17
# WARNING:root:Mx [6.02] is lesser than Mmin [6.50] for fault with name  |  and id 17
# WARNING:root:Dip direction value is missing for fault with name |  and id 18
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 18
# WARNING:root:Dip direction value is missing for fault with name |  and id 19
# WARNING:root:Mx [6.33] is lesser than Mmin [6.50] for fault with name  |  and id 19
# WARNING:root:Dip direction value is missing for fault with name |  and id 20
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 20
# WARNING:root:Dip direction value is missing for fault with name |  and id 21
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 21
# WARNING:root:Dip direction value is missing for fault with name |  and id 22
# WARNING:root:Dip direction value is missing for fault with name |  and id 23
# WARNING:root:Dip direction value is missing for fault with name |  and id 24
#  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [24.5, None, None]
# shortening_rate=  [-24.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.2, None, None]
# mech: Spreading
# Dip value for id= 15 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 15 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 15 is net_slip= 22.05 [slipr = Spreading Ridge]
# mean_azimuth=  91.8765292172
# slip_rate=  22.05
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [24.8, None, None]
# shortening_rate=  [-24.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [3.6, None, None]
# mech: Spreading
# Dip value for id= 16 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 16 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 16 is net_slip= 22.32 [slipr = Spreading Ridge]
# mean_azimuth=  90.4551784845
# slip_rate=  22.32
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [25.0, None, None]
# shortening_rate=  [0.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [25.0, None, None]
# mech: Sinistral
# Dip value for id= 17 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 17 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 17 is net_slip= 22.5 [slipr = Sinistral]
# mean_azimuth=  174.613440301
# slip_rate=  22.5
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [25.3, None, None]
# shortening_rate=  [-25.0, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.1, None, None]
# mech: Spreading
# Dip value for id= 18 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 18 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 18 is net_slip= 22.77 [slipr = Spreading Ridge]
# mean_azimuth=  92.4492921258
# slip_rate=  22.77
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [25.9, None, None]
# shortening_rate=  [-25.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.7, None, None]
# mech: Spreading
# Dip value for id= 19 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 19 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 19 is net_slip= 23.31 [slipr = Spreading Ridge]
# mean_azimuth=  93.9029452275
# slip_rate=  23.31
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [26.3, None, None]
# shortening_rate=  [-25.0, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [8.3, None, None]
# mech: Spreading
# Dip value for id= 20 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 20 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 20 is net_slip= 23.67 [slipr = Spreading Ridge]
# mean_azimuth=  102.126216402
# slip_rate=  23.67
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [26.8, None, None]
# shortening_rate=  [-26.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.3, None, None]
# mech: Spreading
# Dip value for id= 21 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 21 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 21 is net_slip= 24.12 [slipr = Spreading Ridge]
# mean_azimuth=  92.9373344277
# slip_rate=  24.12
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [27.1, None, None]
# shortening_rate=  [1.8, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [27.1, None, None]
# mech: Sinistral
# Dip value for id= 22 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 22 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 22 is net_slip= 24.39 [slipr = Sinistral]
# mean_azimuth=  178.857252892
# slip_rate=  24.39
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [27.7, None, None]
# shortening_rate=  [-27.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [3.0, None, None]
# mech: Spreading
# Dip value for id= 23 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 23 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 23 is net_slip= 24.93 [slipr = Spreading Ridge]
# mean_azimuth=  92.5556026544
# slip_rate=  24.93
# right
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 24
# WARNING:root:Dip direction value is missing for fault with name |  and id 25
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 25
# WARNING:root:Dip direction value is missing for fault with name |  and id 26
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 26
# WARNING:root:Dip direction value is missing for fault with name |  and id 27
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 27
# WARNING:root:Dip direction value is missing for fault with name |  and id 28
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 28
# WARNING:root:Dip direction value is missing for fault with name |  and id 29
# WARNING:root:Mx [6.15] is lesser than Mmin [6.50] for fault with name  |  and id 29
# WARNING:root:Dip direction value is missing for fault with name |  and id 30
# WARNING:root:Mx [5.36] is lesser than Mmin [6.50] for fault with name  |  and id 30
# WARNING:root:Dip direction value is missing for fault with name |  and id 31
# WARNING:root:Mx [5.66] is lesser than Mmin [6.50] for fault with name  |  and id 31
# WARNING:root:Dip direction value is missing for fault with name |  and id 32
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [28.6, None, None]
# shortening_rate=  [-28.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [1.8, None, None]
# mech: Spreading
# Dip value for id= 24 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 24 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 24 is net_slip= 25.740000000000002 [slipr = Spreading Ridge]
# mean_azimuth=  90.0008078851
# slip_rate=  25.740000000000002
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [29.2, None, None]
# shortening_rate=  [-28.8, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.7, None, None]
# mech: Spreading
# Dip value for id= 25 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 25 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 25 is net_slip= 26.28 [slipr = Spreading Ridge]
# mean_azimuth=  77.0437340056
# slip_rate=  26.28
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [29.9, None, None]
# shortening_rate=  [-29.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [0.5, None, None]
# mech: Spreading
# Dip value for id= 26 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 26 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 26 is net_slip= 26.91 [slipr = Spreading Ridge]
# mean_azimuth=  87.0911463836
# slip_rate=  26.91
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [30.4, None, None]
# shortening_rate=  [-30.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.0, None, None]
# mech: Spreading
# Dip value for id= 27 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 27 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 27 is net_slip= 27.36 [slipr = Spreading Ridge]
# mean_azimuth=  77.9217628882
# slip_rate=  27.36
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [30.9, None, None]
# shortening_rate=  [-30.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [5.1, None, None]
# mech: Spreading
# Dip value for id= 28 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 28 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 28 is net_slip= 27.81 [slipr = Spreading Ridge]
# mean_azimuth=  95.6987952389
# slip_rate=  27.81
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [31.4, None, None]
# shortening_rate=  [-31.4, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [0.5, None, None]
# mech: Spreading
# Dip value for id= 29 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 29 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 29 is net_slip= 28.259999999999998 [slipr = Spreading Ridge]
# mean_azimuth=  84.9494967647
# slip_rate=  28.259999999999998
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [31.7, None, None]
# shortening_rate=  [-31.4, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [3.8, None, None]
# mech: Spreading
# Dip value for id= 30 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 30 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 30 is net_slip= 28.53 [slipr = Spreading Ridge]
# mean_azimuth=  79.5299854267
# slip_rate=  28.53
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [31.8, None, None]
# shortening_rate=  [-25.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [19.4, None, None]
# mech: Spreading
# Dip value for id= 31 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 31 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 31 is net_slip= 28.62 [slipr = Spreading Ridge]
# mean_azimuth=  48.1905905568
# slip_rate=  28.62
# dip_dir fazzula=
# WARNING:root:Dip direction value is missing for fault with name |  and id 33
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 33
# WARNING:root:Dip direction value is missing for fault with name |  and id 34
# WARNING:root:Dip direction value is missing for fault with name |  and id 35
# WARNING:root:Mx [6.33] is lesser than Mmin [6.50] for fault with name  |  and id 35
# WARNING:root:Dip direction value is missing for fault with name |  and id 36
# WARNING:root:Mx [6.33] is lesser than Mmin [6.50] for fault with name  |  and id 36
# WARNING:root:Dip direction value is missing for fault with name |  and id 37
# WARNING:root:Mx [6.20] is lesser than Mmin [6.50] for fault with name  |  and id 37
# WARNING:root:Dip direction value is missing for fault with name |  and id 38
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 38
# WARNING:root:Dip direction value is missing for fault with name |  and id 39
# WARNING:root:Mx [6.33] is lesser than Mmin [6.50] for fault with name  |  and id 39
# WARNING:root:Dip direction value is missing for fault with name |  and id 40
#  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [32.0, None, None]
# shortening_rate=  [-2.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [31.8, None, None]
# mech: Dextral
# Dip value for id= 32 is missing and was computed using slipt= Dextral, new dip= 90.0
# Rake value for id= 32 is missing and was computed using slipt= Dextral, new rake= 180
# net_slip value for id= 32 is net_slip= 28.8 [slipr = Dextral]
# mean_azimuth=  359.845876731
# rld= 51.6705756459, width = 17.0, class= Dextral
# slip_rate=  28.8
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [32.3, None, None]
# shortening_rate=  [-32.0, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.3, None, None]
# mech: Spreading
# Dip value for id= 33 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 33 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 33 is net_slip= 29.069999999999997 [slipr = Spreading Ridge]
# mean_azimuth=  75.5069436197
# slip_rate=  29.069999999999997
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [33.0, None, None]
# shortening_rate=  [-32.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [5.3, None, None]
# mech: Spreading
# Dip value for id= 34 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 34 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 34 is net_slip= 29.7 [slipr = Spreading Ridge]
# mean_azimuth=  74.0770576933
# slip_rate=  29.7
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [33.6, None, None]
# shortening_rate=  [-32.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [8.3, None, None]
# mech: Spreading
# Dip value for id= 35 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 35 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 35 is net_slip= 30.240000000000002 [slipr = Spreading Ridge]
# mean_azimuth=  68.3967739754
# slip_rate=  30.240000000000002
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [34.1, None, None]
# shortening_rate=  [-33.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [6.0, None, None]
# mech: Spreading
# Dip value for id= 36 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 36 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 36 is net_slip= 30.69 [slipr = Spreading Ridge]
# mean_azimuth=  72.6626206435
# slip_rate=  30.69
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [34.3, None, None]
# shortening_rate=  [2.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [34.2, None, None]
# mech: Sinistral
# Dip value for id= 37 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 37 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 37 is net_slip= 30.869999999999997 [slipr = Sinistral]
# mean_azimuth=  176.596807688
# slip_rate=  30.869999999999997
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [34.5, None, None]
# shortening_rate=  [-34.4, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [2.5, None, None]
# mech: Spreading
# Dip value for id= 38 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 38 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 38 is net_slip= 31.05 [slipr = Spreading Ridge]
# mean_azimuth=  87.5537749615
# slip_rate=  31.05
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [34.8, None, None]
# shortening_rate=  [-34.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [7.3, None, None]
# mech: Spreading
# Dip value for id= 39 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 39 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 39 is net_slip= 31.319999999999997 [slipr = Spreading Ridge]
# mean_azimuth=  71.164807156
# slip_rate=  31.319999999999997
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [35.2, None, None]
# shortening_rate=  [-31.7, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [15.4, None, None]
# mech: Spreading
# Dip value for id= 40 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 40 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 40 is net_slip= 31.680000000000003 [slipr = Spreading Ridge]
# mean_azimuth=  57.1131586717
# WARNING:root:Mx [6.15] is lesser than Mmin [6.50] for fault with name  |  and id 40
# WARNING:root:Dip direction value is missing for fault with name |  and id 41
# WARNING:root:Mx [6.02] is lesser than Mmin [6.50] for fault with name  |  and id 41
# WARNING:root:Dip direction value is missing for fault with name |  and id 42
# WARNING:root:Mx [6.33] is lesser than Mmin [6.50] for fault with name  |  and id 42
# WARNING:root:Dip direction value is missing for fault with name |  and id 43
# WARNING:root:Mx [5.66] is lesser than Mmin [6.50] for fault with name  |  and id 43
# WARNING:root:Dip direction value is missing for fault with name |  and id 44
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 44
# WARNING:root:Dip direction value is missing for fault with name |  and id 45
# WARNING:root:Mx [6.02] is lesser than Mmin [6.50] for fault with name  |  and id 45
# WARNING:root:Dip direction value is missing for fault with name |  and id 46
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 46
# WARNING:root:Dip direction value is missing for fault with name |  and id 47
# WARNING:root:Mx [5.41] is lesser than Mmin [6.50] for fault with name  |  and id 47
# WARNING:root:Dip direction value is missing for fault with name |  and id 48
# slip_rate=  31.680000000000003
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [35.5, None, None]
# shortening_rate=  [-4.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [35.2, None, None]
# mech: Dextral
# Dip value for id= 41 is missing and was computed using slipt= Dextral, new dip= 90.0
# Rake value for id= 41 is missing and was computed using slipt= Dextral, new rake= 180
# net_slip value for id= 41 is net_slip= 31.95 [slipr = Dextral]
# mean_azimuth=  0.0
# slip_rate=  31.95
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [35.7, None, None]
# shortening_rate=  [-33.3, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [12.9, None, None]
# mech: Spreading
# Dip value for id= 42 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 42 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 42 is net_slip= 32.13 [slipr = Spreading Ridge]
# mean_azimuth=  61.0160670185
# slip_rate=  32.13
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [36.0, None, None]
# shortening_rate=  [-34.8, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [9.4, None, None]
# mech: Spreading
# Dip value for id= 43 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 43 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 43 is net_slip= 32.4 [slipr = Spreading Ridge]
# mean_azimuth=  66.5115366451
# slip_rate=  32.4
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [36.3, None, None]
# shortening_rate=  [-34.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [10.0, None, None]
# mech: Spreading
# Dip value for id= 44 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 44 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 44 is net_slip= 32.67 [slipr = Spreading Ridge]
# mean_azimuth=  66.0445293515
# slip_rate=  32.67
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [36.5, None, None]
# shortening_rate=  [-11.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [34.8, None, None]
# mech: Sinistral
# Dip value for id= 45 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 45 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 45 is net_slip= 32.85 [slipr = Sinistral]
# mean_azimuth=  154.056267612
# slip_rate=  32.85
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [36.7, None, None]
# shortening_rate=  [-35.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [7.6, None, None]
# mech: Spreading
# Dip value for id= 46 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 46 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 46 is net_slip= 33.03 [slipr = Spreading Ridge]
# mean_azimuth=  70.1628148586
# slip_rate=  33.03
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [37.0, None, None]
# shortening_rate=  [-9.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [35.6, None, None]
# mech: Sinistral
# Dip value for id= 47 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 47 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 47 is net_slip= 33.300000000000004 [slipr = Sinistral]
# mean_azimuth=  156.544505888
# slip_rate=  33.300000000000004
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [37.2, None, None]
# WARNING:root:Mx [6.15] is lesser than Mmin [6.50] for fault with name  |  and id 48
# WARNING:root:Dip direction value is missing for fault with name |  and id 49
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 49
# WARNING:root:Dip direction value is missing for fault with name |  and id 50
# WARNING:root:Mx [5.41] is lesser than Mmin [6.50] for fault with name  |  and id 50
# WARNING:root:Dip direction value is missing for fault with name |  and id 51
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 51
# WARNING:root:Dip direction value is missing for fault with name |  and id 52
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 52
# WARNING:root:Dip direction value is missing for fault with name |  and id 53
# WARNING:root:SRL/RLD value is < 5.0 km for fault with name  |  and id 53
# WARNING:root:Dip direction value is missing for fault with name |  and id 54
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 54
# WARNING:root:Dip direction value is missing for fault with name |  and id 55
# WARNING:root:Mx [6.20] is lesser than Mmin [6.50] for fault with name  |  and id 55
# WARNING:root:Dip direction value is missing for fault with name |  and id 56
# WARNING:root:Mx [5.66] is lesser than Mmin [6.50] for fault with name  |  and id 56
# WARNING:root:Dip direction value is missing for fault with name |  and id 57
# shortening_rate=  [-36.7, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [5.8, None, None]
# mech: Spreading
# Dip value for id= 48 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 48 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 48 is net_slip= 33.480000000000004 [slipr = Spreading Ridge]
# mean_azimuth=  72.933156207
# slip_rate=  33.480000000000004
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [37.5, None, None]
# shortening_rate=  [-37.3, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.0, None, None]
# mech: Spreading
# Dip value for id= 49 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 49 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 49 is net_slip= 33.75 [slipr = Spreading Ridge]
# mean_azimuth=  75.9290912083
# slip_rate=  33.75
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [37.7, None, None]
# shortening_rate=  [-7.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [37.0, None, None]
# mech: Sinistral
# Dip value for id= 50 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 50 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 50 is net_slip= 33.93000000000001 [slipr = Sinistral]
# mean_azimuth=  161.067913059
# slip_rate=  33.93000000000001
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [37.9, None, None]
# shortening_rate=  [-37.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [1.7, None, None]
# mech: Spreading
# Dip value for id= 51 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 51 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 51 is net_slip= 34.11 [slipr = Spreading Ridge]
# mean_azimuth=  79.7152153867
# slip_rate=  34.11
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [38.2, None, None]
# shortening_rate=  [-38.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [1.6, None, None]
# mech: Spreading
# Dip value for id= 52 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 52 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 52 is net_slip= 34.38 [slipr = Spreading Ridge]
# mean_azimuth=  84.2914165688
# slip_rate=  34.38
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [38.3, None, None]
# shortening_rate=  [-23.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [30.5, None, None]
# mech: Spreading
# Dip value for id= 53 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 53 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 53 is net_slip= 34.47 [slipr = Spreading Ridge]
# mean_azimuth=  135.400456657
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [38.5, None, None]
# shortening_rate=  [-38.4, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [2.6, None, None]
# mech: Spreading
# Dip value for id= 54 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 54 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 54 is net_slip= 34.65 [slipr = Spreading Ridge]
# mean_azimuth=  78.1913383038
# slip_rate=  34.65
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [38.7, None, None]
# shortening_rate=  [0.3, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [38.7, None, None]
# mech: Dextral
# Dip value for id= 55 is missing and was computed using slipt= Dextral, new dip= 90.0
# Rake value for id= 55 is missing and was computed using slipt= Dextral, new rake= 180
# net_slip value for id= 55 is net_slip= 34.830000000000005 [slipr = Dextral]
# mean_azimuth=  351.562954999
# slip_rate=  34.830000000000005
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [38.8, None, None]
# shortening_rate=  [-37.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [9.5, None, None]
# mech: Spreading
# Dip value for id= 56 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 56 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 56 is net_slip= 34.92 [slipr = Spreading Ridge]
# mean_azimuth=  67.2466904757
# slip_rate=  34.92
# dip_dir fazzula=
# WARNING:root:Mx [6.20] is lesser than Mmin [6.50] for fault with name  |  and id 57
# WARNING:root:Dip direction value is missing for fault with name |  and id 58
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 58
# WARNING:root:Dip direction value is missing for fault with name |  and id 59
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 59
# WARNING:root:Dip direction value is missing for fault with name |  and id 60
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 60
# WARNING:root:Dip direction value is missing for fault with name |  and id 61
# WARNING:root:Dip direction value is missing for fault with name |  and id 62
# WARNING:root:Dip direction value is missing for fault with name |  and id 63
# WARNING:root:Dip direction value is missing for fault with name |  and id 64
# WARNING:root:Dip direction value is missing for fault with name |  and id 65
# WARNING:root:Mx [6.33] is lesser than Mmin [6.50] for fault with name  |  and id 65
#  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [38.9, None, None]
# shortening_rate=  [1.7, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [38.9, None, None]
# mech: Dextral
# Dip value for id= 57 is missing and was computed using slipt= Dextral, new dip= 90.0
# Rake value for id= 57 is missing and was computed using slipt= Dextral, new rake= 180
# net_slip value for id= 57 is net_slip= 35.01 [slipr = Dextral]
# mean_azimuth=  348.643086042
# slip_rate=  35.01
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [39.2, None, None]
# shortening_rate=  [-38.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.4, None, None]
# mech: Spreading
# Dip value for id= 58 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 58 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 58 is net_slip= 35.28 [slipr = Spreading Ridge]
# mean_azimuth=  74.4918435029
# slip_rate=  35.28
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [39.6, None, None]
# shortening_rate=  [-39.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [2.0, None, None]
# mech: Spreading
# Dip value for id= 59 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 59 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 59 is net_slip= 35.64 [slipr = Spreading Ridge]
# mean_azimuth=  78.1835809196
# slip_rate=  35.64
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [39.9, None, None]
# shortening_rate=  [-39.3, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [6.9, None, None]
# mech: Spreading
# Dip value for id= 60 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 60 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 60 is net_slip= 35.91 [slipr = Spreading Ridge]
# mean_azimuth=  70.6770342966
# slip_rate=  35.91
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [40.1, None, None]
# shortening_rate=  [-3.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [40.0, None, None]
# mech: Dextral
# Dip value for id= 61 is missing and was computed using slipt= Dextral, new dip= 90.0
# Rake value for id= 61 is missing and was computed using slipt= Dextral, new rake= 180
# net_slip value for id= 61 is net_slip= 36.09 [slipr = Dextral]
# mean_azimuth=  354.207672973
# rld= 52.4269145837, width = 17.0, class= Dextral
# slip_rate=  36.09
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [40.2, None, None]
# shortening_rate=  [-2.8, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [40.1, None, None]
# mech: Dextral
# Dip value for id= 62 is missing and was computed using slipt= Dextral, new dip= 90.0
# Rake value for id= 62 is missing and was computed using slipt= Dextral, new rake= 180
# net_slip value for id= 62 is net_slip= 36.18000000000001 [slipr = Dextral]
# mean_azimuth=  352.263186699
# slip_rate=  36.18000000000001
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [40.3, None, None]
# shortening_rate=  [-3.4, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [40.1, None, None]
# mech: Dextral
# Dip value for id= 63 is missing and was computed using slipt= Dextral, new dip= 90.0
# Rake value for id= 63 is missing and was computed using slipt= Dextral, new rake= 180
# net_slip value for id= 63 is net_slip= 36.269999999999996 [slipr = Dextral]
# mean_azimuth=  352.069580457
# slip_rate=  36.269999999999996
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [40.3, None, None]
# shortening_rate=  [-3.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [40.2, None, None]
# mech: Dextral
# Dip value for id= 64 is missing and was computed using slipt= Dextral, new dip= 90.0
# Rake value for id= 64 is missing and was computed using slipt= Dextral, new rake= 180
# net_slip value for id= 64 is net_slip= 36.269999999999996 [slipr = Dextral]
# mean_azimuth=  350.678049453
# slip_rate=  36.269999999999996
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [23.1, None, None]
# shortening_rate=  [-22.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [6.1, None, None]
# mech: Spreading
# Dip value for id= 65 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 65 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 65 is net_slip= 20.790000000000003 [slipr = Spreading Ridge]
# mean_azimuth=  259.789350368
# WARNING:root:Dip direction value is missing for fault with name |  and id 66
# WARNING:root:Mx [6.33] is lesser than Mmin [6.50] for fault with name  |  and id 66
# WARNING:root:Dip direction value is missing for fault with name |  and id 67
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 67
# WARNING:root:Dip direction value is missing for fault with name |  and id 68
# WARNING:root:Dip direction value is missing for fault with name |  and id 69
# WARNING:root:Dip direction value is missing for fault with name |  and id 70
# WARNING:root:Dip direction value is missing for fault with name |  and id 71
# WARNING:root:Dip direction value is missing for fault with name |  and id 72
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 72
# WARNING:root:Dip direction value is missing for fault with name |  and id 73
# WARNING:root:Dip direction value is missing for fault with name |  and id 74
# slip_rate=  20.790000000000003
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [22.4, None, None]
# shortening_rate=  [-20.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [9.6, None, None]
# mech: Spreading
# Dip value for id= 66 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 66 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 66 is net_slip= 20.16 [slipr = Spreading Ridge]
# mean_azimuth=  250.557214006
# slip_rate=  20.16
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [21.7, None, None]
# shortening_rate=  [-16.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [14.0, None, None]
# mech: Spreading
# Dip value for id= 67 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 67 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 67 is net_slip= 19.53 [slipr = Spreading Ridge]
# mean_azimuth=  236.548076351
# slip_rate=  19.53
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [21.0, None, None]
# shortening_rate=  [-16.3, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [13.2, None, None]
# mech: Spreading
# Dip value for id= 68 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 68 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 68 is net_slip= 18.900000000000002 [slipr = Spreading Ridge]
# mean_azimuth=  239.577521715
# slip_rate=  18.900000000000002
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [19.7, None, None]
# shortening_rate=  [-18.2, None, None]
# ...
# net_slip value for id= 280 is net_slip= 71.37 [slipr = Spreading Ridge]
# mean_azimuth=  182.37864324
# slip_rate=  71.37
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [77.4, None, None]
# shortening_rate=  [-77.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [5.8, None, None]
# mech: Spreading
# Dip value for id= 281 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 281 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 281 is net_slip= 69.66000000000001 [slipr = Spreading Ridge]
# mean_azimuth=  192.643743068
# slip_rate=  69.66000000000001
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [75.6, None, None]
# shortening_rate=  [-73.8, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [16.5, None, None]
# mech: Spreading
# Dip value for id= 282 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 282 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 282 is net_slip= 68.03999999999999 [slipr = Spreading Ridge]
# mean_azimuth=  184.654051559
# slip_rate=  68.03999999999999
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [73.1, None, None]
# shortening_rate=  [-73.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [0.2, None, None]
# mech: Spreading
# Dip value for id= 283 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 283 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 283 is net_slip= 65.78999999999999 [slipr = Spreading Ridge]
# mean_azimuth=  197.315009285
# slip_rate=  65.78999999999999
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [71.1, None, None]
# shortening_rate=  [-71.0, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [3.4, None, None]
# mech: Spreading
# Dip value for id= 284 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 284 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 284 is net_slip= 63.989999999999995 [slipr = Spreading Ridge]
# mean_azimuth=  194.874471879
# slip_rate=  63.989999999999995
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [69.4, None, None]
# shortening_rate=  [-69.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [6.6, None, None]
# mech: Spreading
# Dip value for id= 285 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 285 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 285 is net_slip= 62.46000000000001 [slipr = Spreading Ridge]
# mean_azimuth=  192.089826631
# slip_rate=  62.46000000000001
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# WARNING:root:Mx [6.15] is lesser than Mmin [6.50] for fault with name  |  and id 286
# WARNING:root:Dip direction value is missing for fault with name |  and id 287
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 287
# WARNING:root:Dip direction value is missing for fault with name |  and id 288
# WARNING:root:Mx [6.46] is lesser than Mmin [6.50] for fault with name  |  and id 288
# WARNING:root:Dip direction value is missing for fault with name |  and id 289
# WARNING:root:Mx [6.15] is lesser than Mmin [6.50] for fault with name  |  and id 289
# WARNING:root:Dip direction value is missing for fault with name |  and id 290
# WARNING:root:Dip direction value is missing for fault with name |  and id 291
# WARNING:root:Dip direction value is missing for fault with name |  and id 292
# WARNING:root:Dip direction value is missing for fault with name |  and id 293
# WARNING:root:Mx [5.97] is lesser than Mmin [6.50] for fault with name  |  and id 293
# WARNING:root:Dip direction value is missing for fault with name |  and id 294
# sliprt=  [67.6, None, None]
# shortening_rate=  [-67.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [3.0, None, None]
# mech: Spreading
# Dip value for id= 286 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 286 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 286 is net_slip= 60.839999999999996 [slipr = Spreading Ridge]
# mean_azimuth=  195.244415193
# slip_rate=  60.839999999999996
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [65.0, None, None]
# shortening_rate=  [-64.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [4.6, None, None]
# mech: Spreading
# Dip value for id= 287 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 287 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 287 is net_slip= 58.5 [slipr = Spreading Ridge]
# mean_azimuth=  193.925044522
# slip_rate=  58.5
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [61.9, None, None]
# shortening_rate=  [-61.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [9.5, None, None]
# mech: Spreading
# Dip value for id= 288 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 288 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 288 is net_slip= 55.71 [slipr = Spreading Ridge]
# mean_azimuth=  189.379918037
# slip_rate=  55.71
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [59.4, None, None]
# shortening_rate=  [-59.4, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [1.5, None, None]
# mech: Spreading
# Dip value for id= 289 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 289 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 289 is net_slip= 53.46 [slipr = Spreading Ridge]
# mean_azimuth=  199.747545762
# slip_rate=  53.46
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [56.7, None, None]
# shortening_rate=  [-56.7, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [1.1, None, None]
# mech: Spreading
# Dip value for id= 290 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 290 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 290 is net_slip= 51.03 [slipr = Spreading Ridge]
# mean_azimuth=  197.360394271
# slip_rate=  51.03
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [53.2, None, None]
# shortening_rate=  [-53.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [2.3, None, None]
# mech: Spreading
# Dip value for id= 291 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 291 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 291 is net_slip= 47.88 [slipr = Spreading Ridge]
# mean_azimuth=  201.075179791
# slip_rate=  47.88
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [49.6, None, None]
# shortening_rate=  [-48.8, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [9.3, None, None]
# mech: Spreading
# Dip value for id= 292 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 292 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 292 is net_slip= 44.64 [slipr = Spreading Ridge]
# mean_azimuth=  188.003904883
# slip_rate=  44.64
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [47.3, None, None]
# shortening_rate=  [-43.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [19.5, None, None]
# mech: Spreading
# Dip value for id= 293 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 293 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 293 is net_slip= 42.57 [slipr = Spreading Ridge]
# mean_azimuth=  223.297574577
# slip_rate=  42.57
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [45.0, None, None]
# shortening_rate=  [-43.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [11.4, None, None]
# mech: Spreading
# Dip value for id= 294 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 294 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 294 is net_slip= 40.5 [slipr = Spreading Ridge]
# mean_azimuth=  184.446764494
# slip_rate=  40.5
# right
# WARNING:root:Dip direction value is missing for fault with name |  and id 295
# WARNING:root:Dip direction value is missing for fault with name |  and id 296
# WARNING:root:Dip direction value is missing for fault with name |  and id 297
# WARNING:root:Dip direction value is missing for fault with name |  and id 298
# WARNING:root:Dip direction value is missing for fault with name |  and id 299
# WARNING:root:Dip direction value is missing for fault with name |  and id 300
# WARNING:root:Dip direction value is missing for fault with name |  and id 301
# WARNING:root:Mx [6.20] is lesser than Mmin [6.50] for fault with name  |  and id 301
# WARNING:root:Dip direction value is missing for fault with name |  and id 302
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [41.4, None, None]
# shortening_rate=  [-40.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [8.3, None, None]
# mech: Spreading
# Dip value for id= 295 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 295 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 295 is net_slip= 37.26 [slipr = Spreading Ridge]
# mean_azimuth=  188.709375916
# slip_rate=  37.26
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [36.7, None, None]
# shortening_rate=  [-36.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [3.4, None, None]
# mech: Spreading
# Dip value for id= 296 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 296 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 296 is net_slip= 33.03 [slipr = Spreading Ridge]
# mean_azimuth=  205.90216062
# slip_rate=  33.03
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [30.6, None, None]
# shortening_rate=  [-30.5, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [3.1, None, None]
# mech: Spreading
# Dip value for id= 297 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 297 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 297 is net_slip= 27.540000000000003 [slipr = Spreading Ridge]
# mean_azimuth=  205.384626866
# slip_rate=  27.540000000000003
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [83.8, None, None]
# shortening_rate=  [-3.2, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [83.8, None, None]
# mech: Sinistral
# Dip value for id= 298 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 298 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 298 is net_slip= 75.42 [slipr = Sinistral]
# mean_azimuth=  86.9802303654
# slip_rate=  75.42
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [35.2, None, None]
# shortening_rate=  [0.1, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [35.2, None, None]
# mech: Sinistral
# Dip value for id= 299 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 299 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 299 is net_slip= 31.680000000000003 [slipr = Sinistral]
# mean_azimuth=  76.1677505699
# rld= 84.3327803558, width = 17.0, class= Sinistral
# slip_rate=  31.680000000000003
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [37.4, None, None]
# shortening_rate=  [-37.3, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [1.0, None, None]
# mech: Spreading
# Dip value for id= 300 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 300 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 300 is net_slip= 33.66 [slipr = Spreading Ridge]
# mean_azimuth=  187.919774724
# slip_rate=  33.66
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [38.6, None, None]
# shortening_rate=  [-2.8, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [38.5, None, None]
# mech: Sinistral
# Dip value for id= 301 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 301 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 301 is net_slip= 34.74 [slipr = Sinistral]
# mean_azimuth=  272.951681924
# slip_rate=  34.74
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# WARNING:root:Dip direction value is missing for fault with name |  and id 303
# WARNING:root:Dip direction value is missing for fault with name |  and id 304
# WARNING:root:Dip direction value is missing for fault with name |  and id 305
# raket=  (None, None, None)
# sliprt=  [42.0, None, None]
# shortening_rate=  [-41.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [2.9, None, None]
# mech: Spreading
# Dip value for id= 302 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 302 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 302 is net_slip= 37.800000000000004 [slipr = Spreading Ridge]
# mean_azimuth=  192.421894352
# slip_rate=  37.800000000000004
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [45.6, None, None]
# shortening_rate=  [-9.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [44.5, None, None]
# mech: Sinistral
# Dip value for id= 303 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 303 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 303 is net_slip= 41.04 [slipr = Sinistral]
# mean_azimuth=  267.776250945
# slip_rate=  41.04
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [48.6, None, None]
# shortening_rate=  [-48.6, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [2.2, None, None]
# mech: Spreading
# Dip value for id= 304 is missing and was computed using slipt= Spreading Ridge, new dip= 60.0
# Rake value for id= 304 is missing and was computed using slipt= Spreading Ridge, new rake= -90
# net_slip value for id= 304 is net_slip= 43.74 [slipr = Spreading Ridge]
# mean_azimuth=  194.288335451
# slip_rate=  43.74
# right
# dip_dir fazzula=  N
# dipt=  (None, None, None)
# raket=  (None, None, None)
# sliprt=  [22.2, None, None]
# shortening_rate=  [-1.9, None, None]
# vertical_slip_rate=  (None, None, None)
# strike_slip_rate=  [22.1, None, None]
# mech: Sinistral
# Dip value for id= 305 is missing and was computed using slipt= Sinistral, new dip= 90.0
# Rake value for id= 305 is missing and was computed using slipt= Sinistral, new rake= 0
# net_slip value for id= 305 is net_slip= 19.98 [slipr = Sinistral]
# mean_azimuth=  125.478842464
# slip_rate=  19.98
# right

# %%
print(sources[0])

# %%
for src in sources:
    key = 'sf_{:s}'.format(src.source_id)
    assert key not in model.sources
    src.source_id = key
    model.sources[key] = src
oqtkp.models[model_id] = model
oqtkp.save()
